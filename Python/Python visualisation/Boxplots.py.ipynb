# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
custdimen_df=pd.read_csv(r"C:\Users\ACER\Desktop\Data Science\Visuslisation_python\Session3+-+Categorical+Data+++Time+Series\global_sales_data\cust_dimen.csv")
marketfact_df=pd.read_csv(r"C:\Users\ACER\Desktop\Data Science\Visuslisation_python\Session3+-+Categorical+Data+++Time+Series\global_sales_data\market_fact.csv")
orders_df=pd.read_csv(r"C:\Users\ACER\Desktop\Data Science\Visuslisation_python\Session3+-+Categorical+Data+++Time+Series\global_sales_data\orders_dimen.csv")
prod_df=pd.read_csv(r"C:\Users\ACER\Desktop\Data Science\Visuslisation_python\Session3+-+Categorical+Data+++Time+Series\global_sales_data\prod_dimen.csv")
shipping_df=pd.read_csv(r"C:\Users\ACER\Desktop\Data Science\Visuslisation_python\Session3+-+Categorical+Data+++Time+Series\global_sales_data\shipping_dimen.csv")
df = pd.merge(marketfact_df, prod_df,  how='inner', on='Prod_id')

#df.head()
sns.boxplot(x='Product_Category', y='Sales', data=df)
plt.yscale('log')
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
custdimen_df=pd.read_csv(r"C:\Users\ACER\Desktop\Data Science\Visuslisation_python\Session3+-+Categorical+Data+++Time+Series\global_sales_data\cust_dimen.csv")
marketfact_df=pd.read_csv(r"C:\Users\ACER\Desktop\Data Science\Visuslisation_python\Session3+-+Categorical+Data+++Time+Series\global_sales_data\market_fact.csv")
orders_df=pd.read_csv(r"C:\Users\ACER\Desktop\Data Science\Visuslisation_python\Session3+-+Categorical+Data+++Time+Series\global_sales_data\orders_dimen.csv")
prod_df=pd.read_csv(r"C:\Users\ACER\Desktop\Data Science\Visuslisation_python\Session3+-+Categorical+Data+++Time+Series\global_sales_data\prod_dimen.csv")
shipping_df=pd.read_csv(r"C:\Users\ACER\Desktop\Data Science\Visuslisation_python\Session3+-+Categorical+Data+++Time+Series\global_sales_data\shipping_dimen.csv")
df_1= pd.merge(df,custdimen_df,how='inner',on='Cust_id')
sns.boxplot(x='Customer_Segment', y='Profit', hue="Product_Category", data=df_1)
plt.show()
